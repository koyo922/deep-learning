# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:39, 784KB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
# %%time

## Your code here
import pandas as pd
from IPython.display import display
s = pd.Series(int_words)
thres = 1e-5
freq = s.value_counts() / s.size # 注意要除总size才是频率
p_drop = 1 - np.sqrt(thres / s.map(freq))
# 注意写法： random < p_keep = 1 - p_drop 或者 random > p_drop
train_words = s.loc[np.random.random_sample(s.shape[0]) > p_drop].values
display([int_to_vocab[w] for w in train_words[:5]],  train_words.size)
# 有随机化，跟标准答案不同很正常
# Out:
# ['anarchism', 'originated', 'term', 'abuse', 'class']
# 4628138
# CPU times: user 5.94 s, sys: 1.02 s, total: 6.96 s
# Wall time: 6.57 s

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    # Your code here
    R = np.random.randint(1,window_size+1)
    start = idx - R if (idx-R) > 0 else 0 # 注意不要出现负下标
    stop = idx + R
    # 注意去掉当前词，去重,stop+1,注意我的答案里这里不是list而是ndarray（相加会广播而非拼接）
#     display(words[start:idx], words[idx+1:stop+1])
#     display(np.concatenate(words[start:idx], words[idx+1:stop+1]))
    targets = set(np.concatenate([words[start:idx], words[idx+1:stop+1]]))
    return list(targets) #  后方需要list

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
arr1 = []
arr2 = [2,3,5,3,3,4]
# set( np.concatenate([np.array(arr1), np.array(arr2)]))
set(arr1+arr2)
# Out:
# {2, 3, 4, 5}

# %%
from itertools import zip_longest
# for x,y in zip_longest([3], [1,5,8],fillvalue=3):
#     print(x,y)

def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        # 注意，后面要求返回的是每个batch的x和y
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(dtype=tf.int32, shape=[None], name='inputs')
    labels = tf.placeholder(dtype=tf.int32, shape=[None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform([n_vocab, n_embedding], -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal([n_vocab, n_embedding],stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w,softmax_b,
                                      labels, embed,
                                      n_sampled, n_vocab)
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
import random
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6687 0.0911 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6312 0.0911 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4937 0.0907 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5912 0.0908 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5302 0.0903 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.4941 0.0904 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5383 0.0905 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5422 0.0908 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4650 0.0912 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4532 0.0905 sec/batch
# Nearest to five: bridged, honey, accessory, stewart, abnormalities, motorist, bender, annotated,
# Nearest to more: outline, attempt, miming, wiggle, sir, bishops, thaw, oppress,
# Nearest to were: eligible, gath, culminating, allotted, onions, bloch, aap, asamiya,
# Nearest to state: somalia, bpaa, hunts, ola, commodores, depatie, iaea, stormy,
# Nearest to d: changing, kenyan, cavett, glagolitic, thaddeus, individually, chih, lossless,
# Nearest to than: minotaurs, alright, deflate, lover, candidates, advising, astringent, bv,
# Nearest to th: hippolyte, pec, unwillingness, alexander, histories, godel, acidic, battra,
# Nearest to however: reduction, suzaku, provocation, standish, incrementing, doubleday, fetishism, premiums,
# Nearest to file: agoraphobic, sparse, kleiner, archaeopteryx, lasalle, masterworks, ultramarine, courts,
# Nearest to operating: hoover, must, delambre, caseless, alphorn, ibu, fulani, ims,
# Nearest to dr: knives, referral, roms, weeping, photographic, indonesian, ostpolitik, bigotry,
# Nearest to orthodox: loss, formulates, requirement, downgraded, charts, petersburg, steadfast, topological,
# Nearest to egypt: dreyer, aino, favored, hiddenstructure, incapacitation, persistence, gcvo, victimization,
# Nearest to older: semigroup, booch, conductance, montage, theresia, obtaining, quod, conceptual,
# Nearest to writers: whitehaven, succulent, unstructured, come, checkpoints, lega, curbed, coworkers,
# Nearest to square: weimar, chimes, negro, opencores, volgograd, kyu, antiquities, livius,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4664 0.0921 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3628 0.0904 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3283 0.0909 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2460 0.0902 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2188 0.0903 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1560 0.0903 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1021 0.0906 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0516 0.0906 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0083 0.0902 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9942 0.0912 sec/batch
# Nearest to five: honey, bridged, motorist, stewart, unfortunate, accessory, annotated, abnormalities,
# Nearest to more: outline, attempt, bishops, wiggle, unified, sir, univ, wasn,
# Nearest to were: eligible, allotted, upon, book, gath, tenure, bloch, culminating,
# Nearest to state: somalia, methodology, trailer, stations, depatie, stormy, list, india,
# Nearest to d: changing, individually, walter, muse, city, socially, authorities, equally,
# Nearest to than: minotaurs, alright, s, advising, candidates, lover, deflate, kabul,
# Nearest to th: histories, provides, acidic, unwillingness, competed, alexander, abbott, size,
# Nearest to however: reduction, wins, impossible, eccentric, suzaku, scaling, relay, ac,
# Nearest to file: archaeopteryx, agoraphobic, crust, courts, sparse, kleiner, masterworks, lasalle,
# Nearest to operating: must, hoover, ibu, series, falsifiable, alphorn, crystallizes, ims,
# Nearest to dr: by, accused, photographic, knives, indonesian, referral, roms, come,
# Nearest to orthodox: loss, requirement, charts, topological, petersburg, let, educators, anywhere,
# Nearest to egypt: favored, dreyer, aino, gcvo, marseillaise, hiddenstructure, persistence, bene,
# Nearest to older: obtaining, montage, semigroup, implemented, horses, alba, conceptual, falsification,
# Nearest to writers: succulent, whitehaven, come, checkpoints, unstructured, believed, tic, didn,
# Nearest to square: weimar, negro, g, opencores, virtual, chimes, followed, antiquities,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9554 0.0923 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8898 0.0905 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8640 0.0909 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8520 0.0908 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.7990 0.0905 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8349 0.0909 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7936 0.0909 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7927 0.0903 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7786 0.0911 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7766 0.0907 sec/batch
# Nearest to five: annotated, bridged, dien, stewart, honey, abnormalities, seven, motorist,
# Nearest to more: outline, bishops, attempt, wiggle, oppress, suvs, unified, univ,
# Nearest to were: eligible, allotted, mainland, unicameral, businesses, tenure, bloch, onions,
# Nearest to state: somalia, methodology, trailer, hunts, electrodynamics, bpaa, depatie, castille,
# Nearest to d: changing, walter, muse, posthumous, thaddeus, individually, kenyan, favoring,
# Nearest to than: minotaurs, lover, deflate, candidates, friday, alright, acquire, wells,
# Nearest to th: alexander, histories, unwillingness, competed, reed, finnish, weakening, acidic,
# Nearest to however: reduction, wins, impossible, eccentric, incrementing, ac, suzaku, doubleday,
# Nearest to file: archaeopteryx, courts, crust, sparse, agoraphobic, directions, sinks, kleiner,
# Nearest to operating: must, hoover, falsifiable, ibu, crystallizes, rpgs, alphorn, reexports,
# Nearest to dr: referral, photographic, by, accused, indonesian, rand, knives, bigotry,
# Nearest to orthodox: petersburg, loss, charts, requirement, acids, educators, topological, relocate,
# Nearest to egypt: favored, gcvo, dreyer, persistence, marseillaise, aino, bene, enslavement,
# Nearest to older: obtaining, semigroup, montage, motivations, falsification, conceptual, conductance, alba,
# Nearest to writers: succulent, whitehaven, checkpoints, tic, come, unstructured, curbed, welcomed,
# Nearest to square: weimar, negro, virtual, opencores, village, antiquities, distances, g,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7960 0.0917 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7746 0.0905 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7094 0.0908 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7055 0.0910 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7405 0.0914 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7117 0.0909 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7157 0.0907 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7208 0.0910 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7163 0.0905 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6683 0.0905 sec/batch
# Nearest to five: one, seven, stewart, puerto, dien, annotated, mesopotamia, athena,
# Nearest to more: bishops, outline, attempt, oppress, suvs, wiggle, prudent, jolly,
# Nearest to were: eligible, allotted, unicameral, mainland, upon, bloch, businesses, aap,
# Nearest to state: somalia, trailer, india, methodology, hunts, widened, bpaa, handicap,
# Nearest to d: kenyan, walter, nine, cavett, changing, muse, posthumous, intellects,
# Nearest to than: deflate, minotaurs, contractual, astringent, persecute, lover, wells, react,
# Nearest to th: alexander, competed, histories, mississippi, reed, godel, weakening, unwillingness,
# Nearest to however: reduction, eccentric, wins, impossible, ac, incrementing, suzaku, ascending,
# Nearest to file: archaeopteryx, courts, crust, agoraphobic, sparse, aesop, tool, lasalle,
# Nearest to operating: must, falsifiable, hoover, crystallizes, hearn, architecture, alphorn, rpgs,
# Nearest to dr: referral, indonesian, weeping, bigotry, druze, obfuscated, rand, photographic,
# Nearest to orthodox: petersburg, relocate, loss, nchhausen, educators, acids, charts, weddings,
# Nearest to egypt: favored, dreyer, gcvo, bene, persistence, marseillaise, intelligently, aino,
# Nearest to older: semigroup, montage, motivations, falsification, obtaining, conductance, conceptual, horses,
# Nearest to writers: whitehaven, succulent, checkpoints, tic, unstructured, longed, taylor, lega,
# Nearest to square: weimar, negro, opencores, virtual, village, yorktown, assure, kyu,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6509 0.0918 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6531 0.0914 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6351 0.0906 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6232 0.0910 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6142 0.0908 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6195 0.0908 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5758 0.0660 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5442 0.0911 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5231 0.0908 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5017 0.0906 sec/batch
# Nearest to five: one, seven, stewart, dien, puerto, four, nine, ek,
# Nearest to more: bishops, outline, oppress, suvs, attempt, wiggle, molinari, vannevar,
# Nearest to were: eligible, allotted, unicameral, aventine, headingley, upon, mainland, culminating,
# Nearest to state: somalia, india, tls, widened, hunts, castille, bpaa, trailer,
# Nearest to d: walter, nine, b, kenyan, sculptor, duke, one, cavett,
# Nearest to than: deflate, areas, astringent, contractual, acquire, minotaurs, narcotic, persecute,
# Nearest to th: alexander, competed, weakening, mississippi, godel, gpo, maneuvering, reed,
# Nearest to however: reduction, eccentric, ascending, incrementing, wins, impossible, suzaku, bends,
# Nearest to file: archaeopteryx, crust, agoraphobic, courts, tool, aesop, sparse, secretes,
# Nearest to operating: must, architecture, falsifiable, hearn, crystallizes, desktop, alphorn, compatible,
# Nearest to dr: referral, obfuscated, rand, indonesian, weeping, hermits, druze, hans,
# Nearest to orthodox: petersburg, relocate, nchhausen, loss, weddings, charts, rexx, methanol,
# Nearest to egypt: favored, dreyer, gcvo, intelligently, marseillaise, bene, portuguese, cryptanalytic,
# Nearest to older: semigroup, falsification, conductance, motivations, montage, obtaining, tagging, flurry,
# Nearest to writers: whitehaven, succulent, tic, checkpoints, unstructured, cnbc, longed, taylor,
# Nearest to square: weimar, negro, village, assure, volgograd, yorktown, opencores, virtual,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4944 0.0919 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5054 0.0906 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4541 0.0906 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5123 0.0907 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4701 0.0909 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4827 0.0907 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4412 0.0912 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3893 0.0912 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4291 0.0908 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4509 0.0904 sec/batch
# Nearest to five: seven, one, stewart, est, dien, ek, puerto, spartan,
# Nearest to more: oppress, bishops, suvs, outline, wiggle, molinari, attempt, unified,
# Nearest to were: eligible, aventine, upon, headingley, allotted, succinctly, mainland, culminating,
# Nearest to state: somalia, india, tls, castille, widened, bpaa, balboa, hunts,
# Nearest to d: walter, kenyan, sculptor, cavett, muse, posthumous, duke, b,
# Nearest to than: deflate, astringent, areas, contractual, narcotic, acquire, bv, react,
# Nearest to th: alexander, competed, weakening, maneuvering, gpo, godel, reed, banque,
# Nearest to however: reduction, ascending, eccentric, wins, premiums, suzaku, uncountable, impossible,
# Nearest to file: archaeopteryx, tool, crust, agoraphobic, sparse, easily, aesop, secretes,
# Nearest to operating: architecture, desktop, proprietary, must, falsifiable, crystallizes, compatible, hearn,
# Nearest to dr: referral, obfuscated, rand, druze, indonesian, weeping, hermits, hans,
# Nearest to orthodox: petersburg, relocate, nchhausen, church, christian, churches, methanol, bostonians,
# Nearest to egypt: favored, dreyer, gcvo, portuguese, marseillaise, bene, intelligently, bergamo,
# Nearest to older: falsification, semigroup, motivations, conductance, tagging, montage, socialistic, obtaining,
# Nearest to writers: whitehaven, tic, succulent, unstructured, cnbc, checkpoints, longed, taylor,
# Nearest to square: negro, village, weimar, rapidity, volgograd, beaux, opencores, softly,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4422 0.0919 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4255 0.0909 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4449 0.0907 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4309 0.0908 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.3899 0.0906 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4256 0.0906 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3844 0.0909 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3697 0.0906 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4241 0.0907 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3597 0.0902 sec/batch
# Nearest to five: seven, one, stewart, four, est, ek, dien, shenzhen,
# Nearest to more: suvs, bishops, oppress, outline, wiggle, unified, attempt, deliveries,
# Nearest to were: eligible, allotted, aventine, upon, headingley, generalissimo, peddle, succinctly,
# Nearest to state: somalia, tls, india, bpaa, judiciary, its, widened, methodology,
# Nearest to d: walter, sculptor, kenyan, cavett, posthumous, muse, b, w,
# Nearest to than: astringent, deflate, not, areas, bv, epidemics, react, contractual,
# Nearest to th: alexander, competed, banque, richard, gpo, abbott, waterfront, weakening,
# Nearest to however: reduction, premiums, ascending, eccentric, uncountable, protoscience, wins, impossible,
# Nearest to file: archaeopteryx, tool, agoraphobic, crust, dimension, aesop, sparse, easily,
# Nearest to operating: proprietary, desktop, compatible, architecture, hearn, risc, falsifiable, alphorn,
# Nearest to dr: francis, obfuscated, rand, druze, edgar, hermits, david, hathaway,
# Nearest to orthodox: petersburg, churches, church, christian, christians, relocate, nchhausen, roman,
# Nearest to egypt: gcvo, dreyer, favored, portuguese, cryptanalytic, bene, kingdom, bergamo,
# Nearest to older: falsification, semigroup, motivations, conductance, tagging, socialistic, alba, ciphers,
# Nearest to writers: whitehaven, tic, succulent, checkpoints, cnbc, longed, taylor, unstructured,
# Nearest to square: village, negro, weimar, carpentry, collisions, rapidity, ranges, distances,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3969 0.0921 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3799 0.0906 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3595 0.0914 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3771 0.0911 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3945 0.0908 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3683 0.0905 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.4017 0.0914 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3876 0.0910 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3446 0.0908 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3490 0.0906 sec/batch
# Nearest to five: one, seven, four, shenzhen, three, stewart, ek, est,
# Nearest to more: suvs, oppress, attempt, bishops, wiggle, discernible, available, warps,
# Nearest to were: eligible, aventine, allotted, kauravas, megabats, generalissimo, reinsurance, angola,
# Nearest to state: somalia, judiciary, tls, india, bpaa, federal, widened, its,
# Nearest to d: walter, sculptor, kenyan, posthumous, w, cavett, muse, wikisource,
# Nearest to than: astringent, deflate, not, areas, epidemics, contractual, babington, lucio,
# Nearest to th: alexander, competed, gpo, weakening, banque, ecumenism, sanatan, richard,
# Nearest to however: reduction, protoscience, premiums, impossible, ascending, incrementing, bends, eccentric,
# Nearest to file: tool, archaeopteryx, dimension, secretes, aesop, agoraphobic, crust, incrementing,
# Nearest to operating: proprietary, desktop, architecture, compatible, risc, companies, falsifiable, alphorn,
# Nearest to dr: francis, rand, edgar, obfuscated, druze, weeping, hans, hathaway,
# Nearest to orthodox: petersburg, christian, churches, church, christians, nchhausen, christianity, relocate,
# Nearest to egypt: dreyer, gcvo, portuguese, favored, sheikh, cryptanalytic, bene, ruler,
# Nearest to older: falsification, semigroup, conductance, motivations, higginbotham, flurry, socialistic, tagging,
# Nearest to writers: whitehaven, tic, succulent, cnbc, checkpoints, taylor, magazine, willie,
# Nearest to square: village, negro, kilometers, ranges, rapidity, distances, km, carpentry,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3594 0.0920 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3387 0.0915 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3625 0.0911 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3972 0.0905 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.4048 0.0904 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.3082 0.0909 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3028 0.0908 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3323 0.0908 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2256 0.0910 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2930 0.0906 sec/batch
# Nearest to five: one, seven, four, nine, zero, est, ek, three,
# Nearest to more: suvs, warps, wiggle, attempt, available, oppress, shunga, outline,
# Nearest to were: eligible, aventine, allotted, culminating, reinsurance, generalissimo, papias, still,
# Nearest to state: somalia, judiciary, tls, widened, india, bpaa, federal, its,
# Nearest to d: sculptor, walter, b, kenyan, duke, posthumous, w, german,
# Nearest to than: astringent, areas, not, deflate, epidemics, contractual, lucio, baka,
# Nearest to th: alexander, competed, ecumenism, banque, gpo, natives, archaeological, weakening,
# Nearest to however: reduction, premiums, resembles, provocation, ascending, protoscience, impossible, incrementing,
# Nearest to file: tool, archaeopteryx, dimension, aesop, secretes, agoraphobic, incrementing, pda,
# Nearest to operating: proprietary, desktop, architecture, risc, companies, compatible, falsifiable, delambre,
# Nearest to dr: obfuscated, edgar, francis, rand, david, weeping, hans, lehrer,
# Nearest to orthodox: churches, christian, petersburg, christians, church, nchhausen, relocate, cults,
# Nearest to egypt: gcvo, dreyer, favored, portuguese, sheikh, cryptanalytic, bene, ruler,
# Nearest to older: falsification, semigroup, flurry, higginbotham, ciphers, tagging, conductance, motivations,
# Nearest to writers: whitehaven, tic, cnbc, succulent, taylor, willie, checkpoints, science,
# Nearest to square: village, kilometers, km, ranges, negro, distances, kilometre, collisions,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3116 0.0923 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3071 0.0907 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3655 0.0400 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2675 0.0906 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2213 0.0908 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2174 0.0915 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2497 0.0904 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2014 0.0905 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2188 0.0904 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1736 0.0910 sec/batch
# Nearest to five: one, seven, four, ek, nine, three, zero, shenzhen,
# Nearest to more: suvs, oppress, warps, wiggle, outline, available, freitas, supplemental,
# Nearest to were: eligible, culminating, aventine, disbanded, generalissimo, allotted, reinsurance, succinctly,
# Nearest to state: somalia, judiciary, tls, widened, india, rwanda, federal, bpaa,
# Nearest to d: sculptor, walter, kenyan, b, duke, thaddeus, philippe, alois,
# Nearest to than: deflate, astringent, areas, not, epidemics, baka, contractual, friday,
# Nearest to th: alexander, gpo, natives, competed, ecumenism, banque, century, archaeological,
# Nearest to however: reduction, premiums, protoscience, resembles, impossible, incrementing, provocation, shelled,
# Nearest to file: tool, dimension, archaeopteryx, incrementing, summary, aesop, secretes, noriega,
# Nearest to operating: desktop, risc, companies, proprietary, compatible, architecture, delambre, falsifiable,
# Nearest to dr: obfuscated, rand, francis, lehrer, edgar, hathaway, david, weeping,
# Nearest to orthodox: churches, christian, church, christians, petersburg, nchhausen, ephesus, christianity,
# Nearest to egypt: gcvo, dreyer, favored, portuguese, sheikh, enslavement, deeming, swims,
# Nearest to older: falsification, semigroup, higginbotham, median, socialistic, pillar, flurry, alba,
# Nearest to writers: whitehaven, tic, cnbc, science, taylor, willie, succulent, actors,
# Nearest to square: village, kilometers, kilometre, km, negro, distances, gassed, rapidity,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2551 0.0922 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2147 0.0907 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2335 0.0905 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1384 0.0905 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1907 0.0909 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1753 0.0906 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1983 0.0904 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1901 0.0913 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2078 0.0911 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1917 0.0909 sec/batch
# Nearest to five: seven, one, four, zero, three, two, nine, est,
# Nearest to more: suvs, wiggle, oppress, freitas, warps, outline, shunga, available,
# Nearest to were: eligible, peddle, eea, bovine, succinctly, lifeless, aventine, interrogators,
# Nearest to state: somalia, judiciary, tls, bpaa, bulgakov, federal, india, rwanda,
# Nearest to d: sculptor, walter, kenyan, posthumous, thaddeus, alois, german, oliveira,
# Nearest to than: not, deflate, astringent, epidemics, areas, contractual, exploit, breakbeat,
# Nearest to th: alexander, competed, gpo, sanatan, natives, banque, watchtower, archaeological,
# Nearest to however: reduction, incrementing, resembles, premiums, impossible, shelled, tilburg, uncountable,
# Nearest to file: tool, dimension, archaeopteryx, secretes, incrementing, agoraphobic, aesop, summary,
# Nearest to operating: risc, desktop, proprietary, companies, architecture, delambre, compatible, alphorn,
# Nearest to dr: obfuscated, edgar, lehrer, rand, hathaway, francis, sapho, psychiatrist,
# Nearest to orthodox: christian, churches, christians, church, ephesus, nchhausen, abrahamic, cults,
# Nearest to egypt: dreyer, gcvo, favored, sheikh, enslavement, deeming, bene, portuguese,
# Nearest to older: falsification, semigroup, median, socialistic, higginbotham, radioisotope, households, pillar,
# Nearest to writers: whitehaven, cnbc, tic, science, succulent, taylor, novelists, willie,
# Nearest to square: village, kilometers, kilometre, distances, km, negro, collisions, gassed,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1759 0.0924 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2417 0.0905 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1678 0.0905 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1567 0.0904 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1860 0.0908 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1812 0.0906 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1900 0.0908 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1529 0.0907 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1561 0.0907 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1641 0.0910 sec/batch
# Nearest to five: seven, one, four, zero, two, three, nine, est,
# Nearest to more: wiggle, warps, suvs, outline, oppress, attempt, shunga, freitas,
# Nearest to were: eligible, peddle, interrogators, culminating, aquilegia, eea, aventine, generalissimo,
# Nearest to state: somalia, judiciary, tls, bpaa, bulgakov, federal, rwanda, sovereignty,
# Nearest to d: sculptor, walter, b, kenyan, oliveira, thaddeus, alois, glagolitic,
# Nearest to than: not, epidemics, deflate, astringent, breakbeat, exploit, baka, areas,
# Nearest to th: alexander, sanatan, gpo, natives, competed, banque, watchtower, nd,
# Nearest to however: reduction, shelled, premiums, standish, incrementing, provocation, impossible, resembles,
# Nearest to file: tool, archaeopteryx, agoraphobic, dimension, summary, secretes, lithograph, aesop,
# Nearest to operating: risc, desktop, proprietary, companies, architecture, delambre, rpgs, alphorn,
# Nearest to dr: obfuscated, edgar, rand, hathaway, psychiatrist, lehrer, taunted, haynes,
# Nearest to orthodox: christian, churches, church, ephesus, christians, calvary, christianity, nchhausen,
# Nearest to egypt: dreyer, sheikh, gcvo, favored, enslavement, bene, portuguese, swims,
# Nearest to older: falsification, semigroup, median, higginbotham, alba, socialistic, radioisotope, pillar,
# Nearest to writers: whitehaven, science, succulent, cnbc, tic, taylor, actors, willie,
# Nearest to square: village, kilometre, kilometers, distances, collisions, negro, gassed, rapidity,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2057 0.0921 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1784 0.0911 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1666 0.0909 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1890 0.0908 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1574 0.0911 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1507 0.0907 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1570 0.0908 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1523 0.0915 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1984 0.0912 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2156 0.0907 sec/batch
# Nearest to five: seven, one, four, zero, three, two, nine, eight,
# Nearest to more: wiggle, warps, outline, suvs, oppress, bishops, attempt, freitas,
# Nearest to were: eligible, culminating, aquilegia, interrogators, aventine, peddle, lifeless, generalissimo,
# Nearest to state: somalia, judiciary, bulgakov, tls, its, bpaa, agglomerations, rwanda,
# Nearest to d: sculptor, b, alois, walter, kenyan, thaddeus, oliveira, corneille,
# Nearest to than: breakbeat, friday, not, epidemics, astringent, deflate, husbands, few,
# Nearest to th: alexander, competed, natives, nd, sanatan, century, gpo, archaeological,
# Nearest to however: reduction, shelled, standish, provocation, resembles, incrementing, premiums, discontent,
# Nearest to file: tool, agoraphobic, summary, archaeopteryx, lithograph, courts, secretes, dimension,
# Nearest to operating: risc, desktop, companies, delambre, proprietary, architecture, rpgs, compatible,
# Nearest to dr: lehrer, psychiatrist, obfuscated, edgar, hathaway, rand, taunted, winchilsea,
# Nearest to orthodox: churches, christian, ephesus, church, nchhausen, calvary, christians, methodism,
# Nearest to egypt: sheikh, gcvo, favored, dreyer, enslavement, bene, deeming, cryptanalytic,
# Nearest to older: falsification, median, semigroup, higginbotham, socialistic, pillar, alba, radioisotope,
# Nearest to writers: science, whitehaven, novelists, cnbc, succulent, actors, fiction, taylor,
# Nearest to square: kilometers, kilometre, village, distances, kilometer, km, gassed, collisions,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2315 0.0915 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1495 0.0906 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1357 0.0903 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1417 0.0906 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0550 0.0914 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1231 0.0904 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1462 0.0908 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1396 0.0912 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1744 0.0145 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1145 0.0907 sec/batch
# Nearest to five: seven, four, one, zero, two, three, nine, eight,
# Nearest to more: freitas, suvs, warps, wiggle, chinatown, attempt, guises, shunga,
# Nearest to were: peddle, culminating, aquilegia, eligible, interrogators, serts, obsolete, srgb,
# Nearest to state: somalia, judiciary, tls, agglomerations, bulgakov, bpaa, rwanda, widened,
# Nearest to d: sculptor, b, alois, walter, kenyan, thaddeus, corneille, german,
# Nearest to than: breakbeat, astringent, not, increases, epidemics, deflate, few, areas,
# Nearest to th: alexander, competed, gpo, natives, nd, century, sanatan, pluralism,
# Nearest to however: reduction, incrementing, resembles, standish, premiums, shelled, impossible, protoscience,
# Nearest to file: tool, agoraphobic, summary, lithograph, archaeopteryx, secretes, incrementing, ftp,
# Nearest to operating: risc, desktop, companies, proprietary, delambre, architecture, rpgs, compatible,
# Nearest to dr: obfuscated, psychiatrist, lehrer, hathaway, newt, rand, sapho, winchilsea,
# Nearest to orthodox: ephesus, christian, churches, calvary, church, christians, nchhausen, methodism,
# Nearest to egypt: sheikh, favored, gcvo, dreyer, bene, enslavement, deeming, cryptanalytic,
# Nearest to older: median, falsification, semigroup, radioisotope, higginbotham, ciphers, socialistic, equivalents,
# Nearest to writers: science, novelists, whitehaven, succulent, cnbc, actors, fiction, tic,
# Nearest to square: kilometre, kilometers, village, distances, yorktown, residential, gassed, kilometer,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0656 0.0926 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0626 0.0915 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.1006 0.0908 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0456 0.0907 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0521 0.0908 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0462 0.0908 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0984 0.0905 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.1309 0.0911 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1137 0.0908 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0216 0.0908 sec/batch
# Nearest to five: seven, four, one, zero, two, three, nine, eight,
# Nearest to more: freitas, suvs, chinatown, warps, demographics, wiggle, shunga, guises,
# Nearest to were: culminating, peddle, aquilegia, obsolete, successor, interrogators, still, aventine,
# Nearest to state: somalia, judiciary, tls, bulgakov, rwanda, agglomerations, federal, widened,
# Nearest to d: sculptor, kenyan, glagolitic, thaddeus, walter, alois, breckinridge, oliveira,
# Nearest to than: increases, epidemics, deflate, not, breakbeat, astringent, few, areas,
# Nearest to th: nd, gpo, competed, alexander, sanatan, pluralism, natives, century,
# Nearest to however: reduction, shelled, premiums, incrementing, standish, resembles, ciliates, disestablished,
# Nearest to file: tool, summary, agoraphobic, lithograph, ftp, archaeopteryx, addressable, incrementing,
# Nearest to operating: risc, desktop, companies, ipc, proprietary, delambre, rpgs, compatible,
# Nearest to dr: obfuscated, psychiatrist, lehrer, newt, sapho, miscarriage, hathaway, taunted,
# Nearest to orthodox: christian, ephesus, churches, calvary, church, methodism, christians, christianity,
# Nearest to egypt: favored, dreyer, sheikh, gcvo, enslavement, bene, muratorian, deeming,
# Nearest to older: median, falsification, semigroup, households, socialistic, alba, radioisotope, higginbotham,
# Nearest to writers: novelists, science, whitehaven, succulent, actors, cnbc, fiction, taylor,
# Nearest to square: kilometre, village, kilometers, distances, residential, yorktown, negro, improv,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0460 0.0924 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0247 0.0909 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0020 0.0906 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0785 0.0908 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0715 0.0909 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0372 0.0906 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0558 0.0908 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1041 0.0905 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0904 0.0908 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0407 0.0905 sec/batch
# Nearest to five: seven, four, one, zero, three, two, nine, years,
# Nearest to more: freitas, warps, demographics, wiggle, chinatown, suvs, shunga, guises,
# Nearest to were: peddle, aquilegia, culminating, obsolete, interrogators, srgb, eligible, serts,
# Nearest to state: tls, somalia, judiciary, bulgakov, bpaa, rwanda, smaller, agglomerations,
# Nearest to d: sculptor, glagolitic, breckinridge, thaddeus, kenyan, alois, b, brookes,
# Nearest to than: increases, deflate, areas, not, astringent, epidemics, breakbeat, transuranic,
# Nearest to th: nd, competed, gpo, century, sanatan, natives, alexander, rd,
# Nearest to however: reduction, incrementing, premiums, shelled, standish, impossible, ciliates, disestablished,
# Nearest to file: tool, agoraphobic, summary, archaeopteryx, secretes, lithograph, addressable, noriega,
# Nearest to operating: risc, desktop, companies, ipc, proprietary, delambre, rpgs, samsung,
# Nearest to dr: psychiatrist, obfuscated, lehrer, miscarriage, newt, sapho, lewiec, hathaway,
# Nearest to orthodox: ephesus, christian, calvary, churches, church, methodism, nchhausen, christians,
# Nearest to egypt: sheikh, favored, gcvo, dreyer, cryptanalytic, enslavement, aino, omar,
# Nearest to older: median, semigroup, falsification, households, socialistic, alba, radioisotope, per,
# Nearest to writers: science, novelists, whitehaven, fiction, succulent, actors, cnbc, sf,
# Nearest to square: kilometre, village, distances, kilometers, residential, saba, yorktown, improv,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0887 0.0929 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0965 0.0912 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0475 0.0909 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0842 0.0905 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0841 0.0906 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0472 0.0908 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0658 0.0908 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0582 0.0914 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0870 0.0908 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0647 0.0910 sec/batch
# Nearest to five: seven, four, one, zero, two, three, nine, years,
# Nearest to more: demographics, freitas, wiggle, guises, warps, chinatown, bishops, population,
# Nearest to were: aquilegia, culminating, eligible, peddle, feudal, successor, generalissimo, literati,
# Nearest to state: judiciary, somalia, tls, bulgakov, rwanda, rede, agglomerations, ministries,
# Nearest to d: glagolitic, breckinridge, gba, thaddeus, sculptor, kenyan, powerplant, deejay,
# Nearest to than: breakbeat, not, friday, deflate, increases, areas, few, astringent,
# Nearest to th: nd, century, competed, pluralism, natives, alexander, sanatan, gpo,
# Nearest to however: reduction, premiums, their, incrementing, standish, impossible, shelled, soundness,
# Nearest to file: tool, agoraphobic, summary, incrementing, addressable, ftp, archaeopteryx, secretes,
# Nearest to operating: risc, desktop, companies, delambre, ospf, rpgs, ipc, proprietary,
# Nearest to dr: psychiatrist, newt, obfuscated, lehrer, miscarriage, sapho, taunted, hathaway,
# Nearest to orthodox: ephesus, christian, calvary, churches, methodism, church, christianity, christians,
# Nearest to egypt: sheikh, favored, dreyer, enslavement, cryptanalytic, omar, gcvo, aino,
# Nearest to older: median, semigroup, falsification, households, alba, socialistic, radioisotope, below,
# Nearest to writers: science, novelists, fiction, actors, succulent, whitehaven, sf, taylor,
# Nearest to square: kilometre, village, residential, kilometers, distances, yorktown, saba, improv,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0551 0.0923 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0342 0.0903 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0039 0.0908 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0852 0.0917 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0694 0.0914 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1490 0.0908 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1288 0.0907 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0570 0.0909 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0392 0.0902 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0454 0.0902 sec/batch
# Nearest to five: seven, four, one, zero, two, three, nine, eight,
# Nearest to more: freitas, demographics, guises, warps, chinatown, population, snail, shunga,
# Nearest to were: aquilegia, culminating, serts, peddle, eligible, interrogators, successor, srgb,
# Nearest to state: judiciary, somalia, tls, bulgakov, rwanda, rede, agglomerations, bpaa,
# Nearest to d: glagolitic, alois, thaddeus, sculptor, breckinridge, kenyan, brookes, palatalization,
# Nearest to than: breakbeat, increases, epidemics, husbands, astringent, deflate, incised, areas,
# Nearest to th: nd, century, competed, natives, gpo, rd, pluralism, twelfth,
# Nearest to however: reduction, incrementing, premiums, experimented, shelled, their, impossible, resembles,
# Nearest to file: agoraphobic, tool, summary, archaeopteryx, ftp, addressable, incrementing, secretes,
# Nearest to operating: risc, desktop, ospf, delambre, companies, ipc, proprietary, rpgs,
# Nearest to dr: psychiatrist, newt, miscarriage, lehrer, sapho, by, obfuscated, lewiec,
# Nearest to orthodox: ephesus, calvary, christian, churches, methodism, nchhausen, metropolitans, christians,
# Nearest to egypt: sheikh, favored, omar, dreyer, cryptanalytic, gcvo, enslavement, aino,
# Nearest to older: median, semigroup, households, falsification, radioisotope, alba, socialistic, equivalents,
# Nearest to writers: novelists, science, actors, winners, fiction, whitehaven, succulent, taylor,
# Nearest to square: kilometre, village, residential, kilometers, distances, yorktown, saba, improv,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9919 0.0926 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 3.9945 0.0916 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0593 0.0916 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0090 0.0906 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0674 0.0910 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0236 0.0798 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0009 0.0910 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9698 0.0915 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0098 0.0908 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9829 0.0908 sec/batch
# Nearest to five: seven, four, one, zero, two, three, nine, eight,
# Nearest to more: demographics, warps, freitas, guises, chinatown, snail, population, superscalar,
# Nearest to were: aquilegia, culminating, peddle, serts, successor, interrogators, srgb, charybdis,
# Nearest to state: tls, judiciary, somalia, bulgakov, rwanda, agglomerations, rede, bpaa,
# Nearest to d: b, sculptor, alois, glagolitic, thaddeus, breckinridge, kenyan, german,
# Nearest to than: breakbeat, increases, areas, astringent, friday, few, considerably, less,
# Nearest to th: nd, century, pluralism, competed, natives, twelfth, gpo, rd,
# Nearest to however: reduction, experimented, shelled, incrementing, resembles, premiums, their, soundness,
# Nearest to file: tool, agoraphobic, summary, addressable, archaeopteryx, ftp, incrementing, lithograph,
# Nearest to operating: risc, desktop, companies, rpgs, hearn, ipc, delambre, overillumination,
# Nearest to dr: psychiatrist, newt, obfuscated, miscarriage, sapho, taunted, lehrer, by,
# Nearest to orthodox: christian, ephesus, calvary, churches, methodism, nchhausen, church, metropolitans,
# Nearest to egypt: sheikh, favored, dreyer, enslavement, cryptanalytic, gcvo, muratorian, aino,
# Nearest to older: median, households, falsification, semigroup, socialistic, alba, equivalents, higginbotham,
# Nearest to writers: novelists, science, fiction, actors, winners, whitehaven, succulent, nominees,
# Nearest to square: kilometre, village, residential, kilometers, distances, downtown, vertices, yorktown,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0146 0.0926 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9596 0.0911 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.9885 0.0906 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0400 0.0912 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0139 0.0906 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9860 0.0909 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9357 0.0909 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9521 0.0911 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9599 0.0905 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9502 0.0909 sec/batch
# Nearest to five: seven, four, one, zero, two, three, nine, six,
# Nearest to more: freitas, demographics, chinatown, warps, population, guises, with, snail,
# Nearest to were: aquilegia, culminating, peddle, feudal, jonah, still, literati, interrogators,
# Nearest to state: judiciary, bulgakov, tls, somalia, rwanda, bpaa, agglomerations, rede,
# Nearest to d: glagolitic, breckinridge, thaddeus, response, sculptor, alois, thabit, gba,
# Nearest to than: breakbeat, few, astringent, less, even, increases, husbands, areas,
# Nearest to th: nd, competed, century, gpo, pluralism, twelfth, natives, subregion,
# Nearest to however: reduction, their, soundness, experimented, ciliates, resembles, impossible, shelled,
# Nearest to file: tool, agoraphobic, archaeopteryx, summary, addressable, ftp, lithograph, courts,
# Nearest to operating: risc, desktop, ipc, rpgs, hearn, companies, delambre, overillumination,
# Nearest to dr: psychiatrist, newt, obfuscated, miscarriage, lewiec, sapho, lehrer, osler,
# Nearest to orthodox: christian, methodism, churches, ephesus, calvary, christians, denominations, metropolitans,
# Nearest to egypt: sheikh, favored, dreyer, cryptanalytic, aino, gcvo, enslavement, omar,
# Nearest to older: median, households, semigroup, falsification, alba, husband, socialistic, household,
# Nearest to writers: novelists, science, fiction, actors, whitehaven, natives, succulent, winners,
# Nearest to square: kilometre, village, residential, kilometers, vertices, distances, kilometer, simcity,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9963 0.0922 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0030 0.0906 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9304 0.0905 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0211 0.0902 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0238 0.0910 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9814 0.0911 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9866 0.0910 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9825 0.0906 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9794 0.0911 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9807 0.0906 sec/batch
# Nearest to five: seven, four, one, zero, two, three, nine, six,
# Nearest to more: demographics, freitas, population, superscalar, guises, performance, with, chinatown,
# Nearest to were: aquilegia, peddle, culminating, jonah, still, feudal, srgb, interrogators,
# Nearest to state: tls, judiciary, bulgakov, bpaa, somalia, translational, cp, rwanda,
# Nearest to d: glagolitic, b, thaddeus, alois, breckinridge, brookes, german, gba,
# Nearest to than: breakbeat, less, few, increases, husbands, astringent, even, considerably,
# Nearest to th: nd, century, competed, twelfth, gpo, pluralism, rd, subregion,
# Nearest to however: their, reduction, soundness, experimented, standish, shelled, manager, disestablished,
# Nearest to file: tool, agoraphobic, summary, archaeopteryx, addressable, lithograph, courts, filesystems,
# Nearest to operating: risc, rpgs, ipc, desktop, hearn, delambre, overillumination, companies,
# Nearest to dr: psychiatrist, newt, obfuscated, miscarriage, sapho, lehrer, lewiec, hathaway,
# Nearest to orthodox: christian, calvary, churches, methodism, ephesus, christians, church, metropolitans,
# Nearest to egypt: sheikh, cryptanalytic, favored, aino, omar, gcvo, arab, dreyer,
# Nearest to older: median, semigroup, households, falsification, alba, household, per, equivalents,
# Nearest to writers: novelists, science, fiction, actors, whitehaven, succulent, natives, genre,
# Nearest to square: kilometre, village, residential, kilometers, vertices, distances, simcity, improv,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0164 0.0922 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9807 0.0908 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9763 0.0908 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0332 0.0909 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0129 0.0907 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0113 0.0906 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9930 0.0906 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9522 0.0905 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9674 0.0902 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0225 0.0906 sec/batch
# Nearest to five: seven, four, one, zero, two, three, nine, six,
# Nearest to more: demographics, population, freitas, superscalar, chinatown, with, attempt, dzie,
# Nearest to were: culminating, aquilegia, successor, literati, feudal, peddle, brought, eligible,
# Nearest to state: judiciary, bulgakov, tls, rwanda, bpaa, ardor, rede, agglomerations,
# Nearest to d: glagolitic, alois, breckinridge, thaddeus, response, brookes, powerplant, deejay,
# Nearest to than: less, have, few, but, considerably, breakbeat, even, increases,
# Nearest to th: nd, twelfth, century, competed, pluralism, rd, subregion, gpo,
# Nearest to however: their, reduction, experimented, soundness, standish, disestablished, shelled, incrementing,
# Nearest to file: agoraphobic, tool, archaeopteryx, summary, addressable, courts, secretes, lithograph,
# Nearest to operating: rpgs, risc, hearn, ipc, delambre, overillumination, companies, ospf,
# ...
# Nearest to d: glagolitic, deejay, rivets, thaddeus, gba, versuch, response, admiralty,
# Nearest to than: less, more, have, but, larger, considerably, even, few,
# Nearest to th: century, nd, twelfth, rd, one, st, thoughout, pluralism,
# Nearest to however: as, their, experimented, it, this, that, but, they,
# Nearest to file: archaeopteryx, agoraphobic, tool, archiver, postscript, filesystems, secretes, summary,
# Nearest to operating: unix, overillumination, ospf, hearn, calc, deification, system, delambre,
# Nearest to dr: psychiatrist, obfuscated, dre, newt, docile, flammarion, transplants, maxwell,
# Nearest to orthodox: calvary, christian, methodism, hermon, eastern, charitable, christians, denominations,
# Nearest to egypt: gcvo, muratorian, sheikh, favored, cryptanalytic, omar, characterises, partridge,
# Nearest to older: median, households, household, family, householder, falsification, equivalents, age,
# Nearest to writers: novelists, fiction, natives, science, actors, sf, skeptics, nominees,
# Nearest to square: kilometre, residential, downtown, village, vertices, improv, socialite, strauss,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8387 0.0924 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8314 0.0911 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8666 0.0912 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8443 0.0907 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8628 0.0905 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8734 0.0913 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8465 0.0913 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8593 0.0910 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8954 0.0907 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8222 0.0910 sec/batch
# Nearest to five: seven, four, zero, one, two, three, six, nine,
# Nearest to more: than, are, with, have, much, lumpy, less, dzie,
# Nearest to were: was, had, brought, been, hittites, early, late, mainly,
# Nearest to state: judiciary, brazauskas, bulgakov, tls, southeastern, radiology, translational, cp,
# Nearest to d: glagolitic, deejay, response, gba, versuch, rivets, thaddeus, admiralty,
# Nearest to than: less, have, more, but, considerably, even, is, larger,
# Nearest to th: century, nd, twelfth, rd, one, pluralism, thoughout, st,
# Nearest to however: their, as, it, but, experimented, confirmed, that, this,
# Nearest to file: archaeopteryx, agoraphobic, tool, postscript, archiver, filesystems, ftp, secretes,
# Nearest to operating: hearn, overillumination, ospf, unix, deification, delambre, calc, system,
# Nearest to dr: psychiatrist, flammarion, newt, obfuscated, docile, dre, maxwell, mcnelly,
# Nearest to orthodox: calvary, christian, methodism, eastern, hermon, charitable, christians, oriental,
# Nearest to egypt: gcvo, sheikh, cryptanalytic, omar, muratorian, characterises, favored, closed,
# Nearest to older: median, households, household, family, equivalents, falsification, semigroup, below,
# Nearest to writers: novelists, fiction, natives, actors, science, genre, sf, births,
# Nearest to square: kilometre, residential, downtown, vertices, village, improv, pentagonal, socialite,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8613 0.0922 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8519 0.0905 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8337 0.0911 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8162 0.0903 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8794 0.0911 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8466 0.0913 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9548 0.0904 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8997 0.0909 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9133 0.0909 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.7997 0.0907 sec/batch
# Nearest to five: seven, four, zero, one, two, three, six, nine,
# Nearest to more: than, are, with, have, less, to, much, lumpy,
# Nearest to were: was, had, brought, been, constructed, early, late, mainly,
# Nearest to state: judiciary, brazauskas, bulgakov, radiology, translational, southeastern, tls, cp,
# Nearest to d: glagolitic, thaddeus, versuch, response, gba, deejay, rivets, balke,
# Nearest to than: less, more, have, but, higher, considerably, larger, transuranic,
# Nearest to th: century, twelfth, nd, rd, one, pluralism, st, gpo,
# Nearest to however: their, but, experimented, as, it, they, confirmed, shelled,
# Nearest to file: archaeopteryx, agoraphobic, postscript, tool, archiver, filesystems, ftp, summary,
# Nearest to operating: hearn, overillumination, ospf, unix, deification, calc, delambre, berber,
# Nearest to dr: psychiatrist, flammarion, maxwell, reabsorbed, kimball, obfuscated, mr, newt,
# Nearest to orthodox: calvary, christian, hermon, weddings, charitable, mandel, methodism, loss,
# Nearest to egypt: gcvo, closed, sheikh, omar, cryptanalytic, characterises, partridge, muratorian,
# Nearest to older: median, households, household, equivalents, family, semigroup, falsification, below,
# Nearest to writers: novelists, fiction, natives, science, actors, people, nominees, births,
# Nearest to square: kilometre, residential, downtown, village, socialite, improv, kilometers, pentagonal,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8162 0.0920 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8619 0.0906 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7633 0.0911 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.9043 0.0908 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8617 0.0914 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8261 0.0912 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8878 0.0437 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8262 0.0915 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8267 0.0912 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8095 0.0911 sec/batch
# Nearest to five: seven, one, four, zero, two, three, six, nine,
# Nearest to more: than, with, are, have, less, much, lumpy, dzie,
# Nearest to were: was, had, brought, have, been, early, constructed, they,
# Nearest to state: judiciary, radiology, brazauskas, bulgakov, cp, southeastern, translational, tls,
# Nearest to d: nine, glagolitic, thaddeus, one, b, response, german, versuch,
# Nearest to than: less, have, more, but, higher, considerably, feuding, is,
# Nearest to th: century, twelfth, nd, rd, one, pluralism, gpo, inroads,
# Nearest to however: but, their, it, experimented, as, that, have, confirmed,
# Nearest to file: archaeopteryx, agoraphobic, tool, postscript, archiver, summary, filesystems, ftp,
# Nearest to operating: hearn, overillumination, ospf, companies, unix, calc, arcnet, system,
# Nearest to dr: psychiatrist, obfuscated, flammarion, reabsorbed, kimball, maxwell, mr, docile,
# Nearest to orthodox: calvary, weddings, hermon, christian, mandel, serbs, xps, charitable,
# Nearest to egypt: gcvo, characterises, muratorian, omar, cryptanalytic, sheikh, pyramids, aino,
# Nearest to older: median, households, household, family, equivalents, falsification, semigroup, householder,
# Nearest to writers: novelists, fiction, natives, science, actors, sf, nominees, people,
# Nearest to square: kilometre, residential, circular, socialite, downtown, village, improv, pentagonal,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8404 0.0924 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8284 0.0912 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8330 0.0909 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7890 0.0910 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8556 0.0914 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8270 0.0906 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8783 0.0909 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7513 0.0910 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8134 0.0908 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7951 0.0904 sec/batch
# Nearest to five: seven, zero, four, one, three, two, six, nine,
# Nearest to more: than, are, with, have, to, less, much, few,
# Nearest to were: had, have, was, early, been, brought, they, dismissed,
# Nearest to state: judiciary, brazauskas, radiology, bulgakov, nadu, tls, cp, translational,
# Nearest to d: glagolitic, response, versuch, deejay, thaddeus, rivets, gba, balke,
# Nearest to than: have, more, less, but, is, even, considerably, as,
# Nearest to th: century, nd, twelfth, rd, one, pluralism, gpo, thoughout,
# Nearest to however: but, as, that, their, this, it, experimented, have,
# Nearest to file: archaeopteryx, agoraphobic, tool, archiver, postscript, filesystems, ftp, summary,
# Nearest to operating: ospf, overillumination, hearn, arcnet, unix, deification, calc, delambre,
# Nearest to dr: psychiatrist, obfuscated, flammarion, reabsorbed, kimball, maxwell, mr, docile,
# Nearest to orthodox: calvary, christian, hermon, christians, patriarchate, methodism, weddings, eastern,
# Nearest to egypt: gcvo, characterises, sheikh, aino, muratorian, pyramids, omar, aswan,
# Nearest to older: median, households, household, below, family, equivalents, falsification, semigroup,
# Nearest to writers: novelists, fiction, natives, science, actors, nominees, sf, people,
# Nearest to square: kilometre, residential, downtown, socialite, pentagonal, village, circular, improv,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7478 0.0920 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8127 0.0907 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8400 0.0911 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8120 0.0907 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8255 0.0907 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8793 0.0910 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8502 0.0918 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8294 0.0908 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8206 0.0909 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8552 0.0909 sec/batch
# Nearest to five: seven, zero, four, one, two, three, six, nine,
# Nearest to more: than, are, with, have, less, much, lumpy, as,
# Nearest to were: had, was, have, they, early, mainly, dismissed, been,
# Nearest to state: judiciary, radiology, translational, brazauskas, bulgakov, cp, southeastern, tls,
# Nearest to d: glagolitic, response, gba, versuch, deejay, rivets, using, thaddeus,
# Nearest to than: more, less, have, but, as, higher, is, even,
# Nearest to th: century, nd, twelfth, rd, one, thoughout, pluralism, gpo,
# Nearest to however: but, their, this, as, that, it, have, experimented,
# Nearest to file: archaeopteryx, agoraphobic, archiver, tool, filesystems, postscript, crust, ftp,
# Nearest to operating: ospf, overillumination, hearn, deification, delambre, unix, arcnet, vices,
# Nearest to dr: psychiatrist, flammarion, kimball, obfuscated, docile, reabsorbed, mcnelly, transplants,
# Nearest to orthodox: calvary, eastern, christian, hermon, oriental, patriarchate, christians, charitable,
# Nearest to egypt: characterises, aino, gcvo, closed, sheikh, pyramids, aswan, partridge,
# Nearest to older: median, households, household, below, age, family, equivalents, falsification,
# Nearest to writers: novelists, fiction, natives, science, genre, sf, actors, nominees,
# Nearest to square: kilometre, residential, socialite, pentagonal, improv, downtown, circular, village,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8921 0.0921 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8226 0.0907 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8350 0.0909 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8552 0.0908 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8731 0.0907 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8313 0.0915 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8400 0.0907 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8673 0.0914 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8015 0.0911 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.7947 0.0907 sec/batch
# Nearest to five: seven, one, zero, four, two, three, six, eight,
# Nearest to more: than, are, with, have, less, few, to, lumpy,
# Nearest to were: had, was, early, been, mainly, have, constructed, they,
# Nearest to state: judiciary, brazauskas, radiology, translational, bulgakov, nadu, southeastern, tls,
# Nearest to d: response, glagolitic, gba, versuch, rivets, deejay, using, thaddeus,
# Nearest to than: less, have, more, but, even, as, considerably, not,
# Nearest to th: century, nd, twelfth, rd, one, thoughout, pluralism, two,
# Nearest to however: but, it, that, their, this, as, confirmed, have,
# Nearest to file: archaeopteryx, agoraphobic, ftp, archiver, filesystems, postscript, tool, summary,
# Nearest to operating: ospf, delambre, deification, hearn, overillumination, unix, vices, arcnet,
# Nearest to dr: psychiatrist, kimball, mcnelly, reabsorbed, flammarion, aldiss, ballantine, obfuscated,
# Nearest to orthodox: calvary, christian, eastern, hermon, patriarchate, ephesus, weddings, serbs,
# Nearest to egypt: characterises, aino, gcvo, sheikh, pyramids, closed, muratorian, omar,
# Nearest to older: median, households, household, family, below, equivalents, falsification, semigroup,
# Nearest to writers: novelists, fiction, natives, science, genre, actors, sf, prolific,
# Nearest to square: kilometre, residential, pentagonal, socialite, improv, divergence, downtown, kilometers,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8577 0.0920 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8013 0.0913 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9138 0.0914 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9201 0.0910 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8765 0.0909 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8354 0.0910 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7961 0.0907 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8082 0.0915 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7563 0.0920 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8637 0.0919 sec/batch
# Nearest to five: zero, seven, four, one, two, three, six, nine,
# Nearest to more: than, are, with, have, less, to, much, as,
# Nearest to were: early, had, was, been, have, brought, mainly, they,
# Nearest to state: judiciary, radiology, brazauskas, southeastern, bulgakov, nadu, cp, pradesh,
# Nearest to d: versuch, glagolitic, nine, response, thaddeus, german, deejay, american,
# Nearest to than: less, more, have, higher, but, considerably, larger, as,
# Nearest to th: century, nd, twelfth, rd, one, pluralism, thoughout, st,
# Nearest to however: but, this, experimented, it, confirmed, that, their, bonomi,
# Nearest to file: archaeopteryx, agoraphobic, filesystems, ftp, archiver, tool, postscript, crust,
# Nearest to operating: ospf, companies, deification, unix, overillumination, hearn, delambre, samsung,
# Nearest to dr: psychiatrist, kimball, reabsorbed, mcnelly, maxwell, asser, selected, aldiss,
# Nearest to orthodox: calvary, hermon, mandel, weddings, eastern, charitable, serbs, christian,
# Nearest to egypt: characterises, aino, gcvo, sheikh, pyramids, closed, omar, muratorian,
# Nearest to older: median, households, household, family, below, equivalents, falsification, semigroup,
# Nearest to writers: novelists, fiction, natives, science, actors, sf, people, nominees,
# Nearest to square: kilometre, residential, improv, pentagonal, socialite, downtown, tiananmen, kilometers,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8625 0.0922 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8142 0.0909 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 50
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
